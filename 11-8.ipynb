# %%
### 넘파이,판다스,매트플랏립 실습

# %%
import numpy as np
import pandas as pd
import matplotlib

# %%
data = np.random.rand(50)
data
# Out:
# array([0.49900747, 0.54680764, 0.3020637 , 0.70011374, 0.32417558,
#        0.17883576, 0.80219316, 0.07820043, 0.21819584, 0.32404613,
#        0.13522139, 0.31164328, 0.05718384, 0.28865105, 0.24407618,
#        0.86277879, 0.9181571 , 0.33754255, 0.69402462, 0.87716912,
#        0.01410615, 0.7890187 , 0.26074658, 0.28908302, 0.1127894 ,
#        0.92290968, 0.95155962, 0.48498518, 0.73694851, 0.52307528,
#        0.16485004, 0.10625667, 0.78101807, 0.68092024, 0.72881505,
#        0.7145828 , 0.51999078, 0.27087818, 0.22988052, 0.03796213,
#        0.60104808, 0.00727427, 0.46635511, 0.49334967, 0.95663556,
#        0.32010598, 0.46055741, 0.86286845, 0.28433504, 0.80680489])

# %%
seri = pd.Series(data) 
seri
# Out:
# 0     0.499007
# 1     0.546808
# 2     0.302064
# 3     0.700114
# 4     0.324176
# 5     0.178836
# 6     0.802193
# 7     0.078200
# 8     0.218196
# 9     0.324046
# 10    0.135221
# 11    0.311643
# 12    0.057184
# 13    0.288651
# 14    0.244076
# 15    0.862779
# 16    0.918157
# 17    0.337543
# 18    0.694025
# 19    0.877169
# 20    0.014106
# 21    0.789019
# 22    0.260747
# 23    0.289083
# 24    0.112789
# 25    0.922910
# 26    0.951560
# 27    0.484985
# 28    0.736949
# 29    0.523075
# 30    0.164850
# 31    0.106257
# 32    0.781018
# 33    0.680920
# 34    0.728815
# 35    0.714583
# 36    0.519991
# 37    0.270878
# 38    0.229881
# 39    0.037962
# 40    0.601048
# 41    0.007274
# 42    0.466355
# 43    0.493350
# 44    0.956636
# 45    0.320106
# 46    0.460557
# 47    0.862868
# 48    0.284335
# 49    0.806805
# dtype: float64

# %%
seri.plot()
# Out:
# <AxesSubplot:>
